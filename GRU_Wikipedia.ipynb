# %%
import torch
import os
import argparse
from torch.utils.data import Dataset, DataLoader
import torchtext
from collections import Counter
import numpy as np
import pandas as pd
import pickle

from numpy import array
from numpy import argmax
from tensorflow.keras.utils import to_categorical

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import SimpleRNN
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
sw = stopwords.words('english') 


class Tokenizer:

    def __init__(self, file, threshold=5):
        self.file = file
        self.data = pd.read_csv(file)
        self.threshold = threshold

    def preprocess(self):
        tokenizer = torchtext.data.utils.get_tokenizer('spacy', language='en')
        tokens = []
        sentence_list=[]
        for text in self.data['text'].tolist():
            tokens.append(tokenizer(text))
            sentence_list.append(text.split('.'))

        self.data['sentences_list'] = sentence_list
        counter = Counter()
        for line in tokens:
            for word in line:
                counter[word] += 1

        mapper = {word[0]: idx+1 for idx,
                  word in enumerate(counter.most_common())}
        inverse_mapper = {idx+1: word[0] for idx,
                          word in enumerate(counter.most_common())}

        # sos_idx = len(counter_threshold.keys())
        # eos_idx = len(counter_threshold.keys()) + 1
        other_idx = len(counter.keys())

        mapped_tokens = []

        for line in tokens:
            mapped_line = []
            for word in line:
              # map words to their mappings and to other otherwise
                mapped_line.append(mapper.get(word, other_idx))
            mapped_tokens.append(mapped_line)

        return mapped_tokens, inverse_mapper




def similarity_paragraph(data):
    # data = self.data
    sim_list = []
    for para in data['sentences_list'].tolist():
      sim = 200
      start = para[0]
      para = para[1:]
      for sent in para:            
        # tokenization
        X_list = word_tokenize(start) 
        Y_list = word_tokenize(sent)
          
        # sw contains the list of stopwords
        l1 =[];l2 =[]
          
        # remove stop words from the string
        X_set = {w for w in X_list if not w in sw} 
        Y_set = {w for w in Y_list if not w in sw}
          
        # form a set containing keywords of both strings 
        rvector = X_set.union(Y_set) 
        for w in rvector:
            if w in X_set: l1.append(1) # create a vector
            else: l1.append(0)
            if w in Y_set: l2.append(1)
            else: l2.append(0)
        c = 0
          
        # cosine formula 
        for i in range(len(rvector)):
            c+= l1[i]*l2[i]
        try:
          cosine = c / float((sum(l1)*sum(l2))**0.5)
          if sim > cosine:
            sim = cosine
        except:
          sim += 0
          
        start = sent
      
      # sim = sim/(len(para)+1)
      sim_list.append(sim)
    
    data['similarity'] = sim_list

    return data
          
          # print("similarity: ", cosine)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# describe the training data here

# %%
# training data
data1 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Clinton_train.csv')
data2 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Yahoo_train.csv')
data3 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Yelp_train.csv')
data4 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Enron_train.csv')

data5 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Yahoo_test.csv')
data6 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Yelp_test.csv')
data7 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Enron_test.csv')
data8 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Enron_test.csv')

# %%
data = pd.concat([data1, data2, data3, data4, data5, data6, data7])

# %%
data.to_csv('/content/gdrive/MyDrive/NLP-Project/new_train.csv')

# %%
train = Tokenizer("/content/gdrive/MyDrive/NLP-Project/new_train.csv")
test = Tokenizer("/content/gdrive/MyDrive/NLP-Project/Clinton_test.csv")

# %%
train = Tokenizer("/content/gdrive/MyDrive/NLP-Project/new_train.csv")
test = Tokenizer("/content/gdrive/MyDrive/NLP-Project/Clinton_test.csv")

# %%
lst = array(train.data['labelA'])
encoded = to_categorical(lst)

# %%
lst = array(test.data['labelA'])
t_encoded = to_categorical(lst)

# %%
train_mapping, inv_train_mapping = train.preprocess()
test_mapping, inv_test_mapping = test.preprocess()

# %% [markdown]
# describe the similarity function here

# %%
train.data = similarity_paragraph(train.data)
test.data = similarity_paragraph(test.data)

# %%
train.data['encoding'] = train_mapping
test.data['encoding'] = test_mapping

# %%
train.data['labelA'][4]
# Out:
# 1

# %% [markdown]
# # LSTM with 4600/200 train/test(Clinton) split 3-way multi-classifier

# %%
np.random.seed(7)
X_train = sequence.pad_sequences(train.data['encoding'],maxlen = 500)
y_train = encoded
X_test = sequence.pad_sequences(test.data['encoding'],maxlen=500)
y_test = t_encoded

# %%
embedding_vector_length = 32
model = Sequential()
model.add(Embedding(40000,embedding_vector_length,input_length = 500))
model.add(LSTM(32,dropout=0.2, return_sequences = True ))
model.add(LSTM(32))
model.add(Dense(4,activation = 'softmax'))
model.compile(loss ='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
print(model.summary())
model.fit(X_train,y_train, epochs = 15, batch_size=23)

scores = model.evaluate(X_test, y_test, verbose =0)
print("Accuracy: ",(scores[1]*100))

# %%
import pickle
filename = 'lstm_binary_min_sim_clinton.sav'
pickle.dump(model,open(filename,'wb'))

# %% [markdown]
# # LSTM with 4600/200 train/test(Clinton) split binary classifier with minimum similarity function

# %%
coh_bin = []
for i in range(4600):
  if train.data['labelA'].tolist()[i] >=2:
    coh_bin.append(1)
  else:
    coh_bin.append(0)
train.data['bin_coh']= coh_bin


coh_bin=[]
for i in range(200):
  if test.data['labelA'].tolist()[i] >=2:
    coh_bin.append(1)
  else:
    coh_bin.append(0)

test.data['bin_coh']=coh_bin

# %%
lst = array(train.data['bin_coh'])
encoded = to_categorical(lst)

lst = array(test.data['bin_coh'])
t_encoded = to_categorical(lst)

# %%
np.random.seed(7)
X_train = sequence.pad_sequences(train.data['encoding'],maxlen = 500)
y_train = encoded#train.data['h_e']
X_test = sequence.pad_sequences(test.data['encoding'],maxlen=500)
y_test = t_encoded#test.data['h_e']

# X_train = np.append(train.data['similarity'][:,np.newaxis], X_train, axis=1)
# X_test = np.append(test.data['similarity'][:,np.newaxis],X_test, axis=1)

# %%
type(X_train)

X_train = np.append(train.data['similarity'][:,np.newaxis], X_train, axis=1)
X_test = np.append(test.data['similarity'][:,np.newaxis],X_test, axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   after removing the cwd from sys.path.

# %%
embedding_vector_length = 32
model = Sequential()
model.add(Embedding(40000,embedding_vector_length,input_length = 501))
model.add(LSTM(32,dropout=0.2, return_sequences = True ))
model.add(LSTM(32))
model.add(Dense(2,activation = 'softmax'))
model.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])
print(model.summary())
model.fit(X_train,y_train, epochs = 15 , batch_size=23)

scores = model.evaluate(X_test, y_test, verbose =0)
print("Accuracy: ",(scores[1]*100))

# %%
np.random.seed(7)
X_train = sequence.pad_sequences(train.data['encoding'],maxlen = 256)
y_train = encoded#train.data['h_e']
X_test = sequence.pad_sequences(test.data['encoding'],maxlen=256)
y_test = t_encoded#test.data['h_e']
X_train = np.append(train.data['similarity'][:,np.newaxis], X_train, axis=1)
X_test = np.append(test.data['similarity'][:,np.newaxis],X_test, axis=1)
embedding_vector_length = 32
model = Sequential()
model.add(Embedding(40000,embedding_vector_length,input_length = 257))
model.add(LSTM(32,dropout=0.2, return_sequences = True ))
model.add(LSTM(32))
model.add(Dense(2,activation = 'softmax'))
model.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])
print(model.summary())
model.fit(X_train,y_train, epochs = 10 , batch_size=23)

scores = model.evaluate(X_test, y_test, verbose =0)
print("Accuracy: ",(scores[1]*100))

# %%
embedding_vector_length = 32
model = Sequential()
model.add(Embedding(40000,embedding_vector_length,input_length = 500))
model.add(LSTM(32,dropout=0.2, return_sequences = True ))
model.add(LSTM(32))
model.add(Dense(2,activation = 'softmax'))
model.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])
print(model.summary())
model.fit(X_train,y_train, epochs = 4 , batch_size=23)

scores = model.evaluate(X_test, y_test, verbose =0)
print("Accuracy: ",(scores[1]*100))

# %%
out.save('/content/gdrive/MyDrive/NLP-Project/model')

# %% [markdown]
# # Best model using the new data

# %%
new_data = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/gitCorpus.csv')

# %%
new_data
# Out:
#                                                       ctx  label  \
# 0       Estramustine (INN, USAN, BAN) (brand names Emc...      0
# 1       L² Puppis (also known as HD 56096) is a giant ...      0
# 2       David John (Davy/Davey) Gunn (1887-1955) was a...      0
# 3       Olivia Hussey (born Olivia Osuna; 17 April 195...      0
# 4       Tailapa II, or Taila, (r.973–997 CE) (or Ahava...      0
# ...                                                   ...    ...
# 179079  -LRB- CNN -RRB- If you listen to rock or pop, ...      1
# 179080  -LRB- CNN -RRB- -- Pirates have struck again, ...      1
# 179081  -LRB- CNN -RRB- -- Russia will begin the const...      1
# 179082  -LRB- CNN -RRB- -- The man police say kidnappe...      1
# 179083  -LRB- CNN -RRB- -- Frostbite has forced Britis...      1
#
#                                            to_be_replaced  train  file_id  \
# 0       It is a derivative of estradiol, an estrogen, ...      0     2202
# 1       This is most likely an asymptotic giant branch...      0     1034
# 2       He covered the 90 kilometre, four day journey ...      0     4180
# 3       She is also well known for her role as Mary, t...      0     1932
# 4       He re-established the Western Chalukya dynasty...      0     8118
# ...                                                   ...    ...      ...
# 179079                                                NaN      1    78526
# 179080                                                NaN      1     8221
# 179081                                                NaN      1    81712
# 179082                                                NaN      1    39783
# 179083                                                NaN      1    18930
#
#                                              replace_with  sen_position  \
# 0       It is the L-alanine ester of estramustine, whi...             1
# 1            It has an apparent visual magnitude of 6.26.             3
# 2       Gunn played a role in the implementation of th...             3
# 3       She is best known for her collaborations with ...             1
# 4       This Kannadiga dynasty is sometimes called the...             1
# ...                                                   ...           ...
# 179079                                                NaN            -1
# 179080                                                NaN            -1
# 179081                                                NaN            -1
# 179082                                                NaN            -1
# 179083                                                NaN            -1
#
#                                              ctx-replaced
# 0       Estramustine (INN, USAN, BAN) (brand names Emc...
# 1       L² Puppis (also known as HD 56096) is a giant ...
# 2       David John (Davy/Davey) Gunn (1887-1955) was a...
# 3       Olivia Hussey (born Olivia Osuna; 17 April 195...
# 4       Tailapa II, or Taila, (r.973–997 CE) (or Ahava...
# ...                                                   ...
# 179079                                                NaN
# 179080                                                NaN
# 179081                                                NaN
# 179082                                                NaN
# 179083                                                NaN
#
# [179084 rows x 8 columns]

# %%
new_train = Tokenizer('/content/gdrive/MyDrive/NLP-Project/gitCorpus.csv')

# %%
new_train.data = new_train.data.drop(['label','to_be_replaced','train','file_id','replace_with','sen_position'],axis = 1)
new_train.data
# Out:
#                                                       ctx  \
# 0       Estramustine (INN, USAN, BAN) (brand names Emc...
# 1       L² Puppis (also known as HD 56096) is a giant ...
# 2       David John (Davy/Davey) Gunn (1887-1955) was a...
# 3       Olivia Hussey (born Olivia Osuna; 17 April 195...
# 4       Tailapa II, or Taila, (r.973–997 CE) (or Ahava...
# ...                                                   ...
# 179079  -LRB- CNN -RRB- If you listen to rock or pop, ...
# 179080  -LRB- CNN -RRB- -- Pirates have struck again, ...
# 179081  -LRB- CNN -RRB- -- Russia will begin the const...
# 179082  -LRB- CNN -RRB- -- The man police say kidnappe...
# 179083  -LRB- CNN -RRB- -- Frostbite has forced Britis...
#
#                                              ctx-replaced
# 0       Estramustine (INN, USAN, BAN) (brand names Emc...
# 1       L² Puppis (also known as HD 56096) is a giant ...
# 2       David John (Davy/Davey) Gunn (1887-1955) was a...
# 3       Olivia Hussey (born Olivia Osuna; 17 April 195...
# 4       Tailapa II, or Taila, (r.973–997 CE) (or Ahava...
# ...                                                   ...
# 179079                                                NaN
# 179080                                                NaN
# 179081                                                NaN
# 179082                                                NaN
# 179083                                                NaN
#
# [179084 rows x 2 columns]

# %%
pos_data = new_train.data[['ctx']].copy()
label = [1]*len(pos_data)
pos_data = pos_data.rename(columns = {'ctx':'text'})
pos_data['label']=label
pos_data
neg_data = new_train.data[['ctx-replaced']].copy()
neg_data = neg_data.rename(columns = {'ctx-replaced':'text'})
# neg_data = neg_data[neg_data['text'] != '' and neg_data['text' != None]]
neg_data = neg_data.dropna()
label = [0]*len(neg_data)
neg_data['label'] = label
neg_data
new_train.data = pd.concat([pos_data,neg_data])
new_train.data
# Out:
#                                                      text  label
# 0       Estramustine (INN, USAN, BAN) (brand names Emc...      1
# 1       L² Puppis (also known as HD 56096) is a giant ...      1
# 2       David John (Davy/Davey) Gunn (1887-1955) was a...      1
# 3       Olivia Hussey (born Olivia Osuna; 17 April 195...      1
# 4       Tailapa II, or Taila, (r.973–997 CE) (or Ahava...      1
# ...                                                   ...    ...
# 142301  -LRB- Fast Company -RRB- -- For years,  employ...      0
# 142302  Paris -LRB- CNN -RRB- -- France will start wit...      0
# 142303  -LRB- CNN -RRB- -- Pinterest is the breakout s...      0
# 142304  New York -LRB- CNN -RRB- -- Officer Rafael Ram...      0
# 142305  -LRB- CNN -RRB- Would a taste of the finest Sw...      0
#
# [264347 rows x 2 columns]

# %%
new_train_mapping, inv_new_train_mapping = new_train.preprocess()
new_train.data['encoding'] = new_train_mapping

new_train.data = similarity_paragraph(new_train.data)

# %%
train_split = new_train.data.sample(frac = 0.8, random_state=200)
test_split = new_train.data.drop(train_split.index)

# %%
train_split
# Out:
#                                                      text  label  \
# 157493  -LRB- CNN -RRB- -- World football 's governing...      1
# 61962   Turrilitidae  is a family of extinct heteromor...      1
# 94326   Digidogheadlock is the eighth album by Japanes...      1
# 118888  London,  England -LRB- CNN -RRB- -- The Britis...      1
# 154898  -LRB- CNN -RRB- -- Inside the Charles Manson r...      1
# ...                                                   ...    ...
# 108315  -LRB- CNN -RRB- -- Nurse Kaci Hickox and her b...      1
# 131663  Cairo,  Egypt -LRB- CNN -RRB- -- Authorities i...      1
# 155532  -LRB- CNN -RRB- -- Pontiac lovers are feeling ...      1
# 115363  Russian Prime Minister Dmitry Medvedev has sig...      1
# 29155   The Jennie Foley Building, also known as the J...      1
#
#                                            sentences_list  \
# 157493  [-LRB- CNN -RRB- -- World football 's governin...
# 61962   [Turrilitidae  is a family of extinct heteromo...
# 94326   [Digidogheadlock is the eighth album by Japane...
# 118888  [London,  England -LRB- CNN -RRB- -- The Briti...
# 154898  [-LRB- CNN -RRB- -- Inside the Charles Manson ...
# ...                                                   ...
# 108315  [-LRB- CNN -RRB- -- Nurse Kaci Hickox and her ...
# 131663  [Cairo,  Egypt -LRB- CNN -RRB- -- Authorities ...
# 155532  [-LRB- CNN -RRB- -- Pontiac lovers are feeling...
# 115363  [Russian Prime Minister Dmitry Medvedev has si...
# 29155   [The Jennie Foley Building, also known as the ...
#
#                                                  encoding  similarity
# 157493  [30, 31, 32, 27, 137, 227, 15, 3497, 447, 2491...    0.100000
# 61962   [337218, 6, 10, 8, 151, 4, 3604, 337219, 26839...    0.000000
# 94326   [394473, 10, 2, 2980, 105, 21, 643, 207, 12, 8...    0.091287
# 118888  [282, 1, 6, 279, 30, 31, 32, 27, 12, 189, 2699...    0.000000
# 154898  [30, 31, 32, 27, 6245, 2, 966, 12012, 1312, 26...    0.109109
# ...                                                   ...         ...
# 108315  [30, 31, 32, 27, 20800, 52617, 34480, 5, 57, 5...    0.108465
# 131663  [2850, 1, 6, 1261, 30, 31, 32, 27, 2114, 7, 12...    0.120386
# 155532  [30, 31, 32, 27, 20349, 9075, 35, 3812, 28369,...    0.070014
# 115363  [555, 949, 483, 14132, 13378, 33, 920, 8, 9333...    0.000000
# 29155   [12, 30671, 13311, 2840, 1, 48, 65, 18, 2, 306...    0.000000
#
# [211478 rows x 5 columns]

# %%
test_split
# Out:
#                                                      text  label  \
# 33      The swimming competitions at the 2016 Summer O...      1
# 56      The Orlando Shakespeare Theater is a theater c...      1
# 67      Histocompatibility, or tissue compatibility, i...      1
# 86      William Morris (January 1, 1861 – January 11, ...      1
# 97      Alphonse Areola (born 27 February 1993) is a F...      1
# ...                                                   ...    ...
# 142202  Tokyo -LRB- CNN -RRB- -- Japanese Prime Minist...      0
# 142231  -LRB- CNN -RRB- -- With a first name that mean...      0
# 142269  -LRB- CNN -RRB- -- As about 2 % of babies born...      0
# 142302  Paris -LRB- CNN -RRB- -- France will start wit...      0
# 142304  New York -LRB- CNN -RRB- -- Officer Rafael Ram...      0
#
#                                            sentences_list  \
# 33      [The swimming competitions at the 2016 Summer ...
# 56      [The Orlando Shakespeare Theater is a theater ...
# 67      [Histocompatibility, or tissue compatibility, ...
# 86      [William Morris (January 1, 1861 – January 11,...
# 97      [Alphonse Areola (born 27 February 1993) is a ...
# ...                                                   ...
# 142202  [Tokyo -LRB- CNN -RRB- -- Japanese Prime Minis...
# 142231  [-LRB- CNN -RRB- -- With a first name that mea...
# 142269  [-LRB- CNN -RRB- -- As about 2 % of babies bor...
# 142302  [Paris -LRB- CNN -RRB- -- France will start wi...
# 142304  [New York -LRB- CNN -RRB- -- Officer Rafael Ra...
#
#                                                  encoding  similarity
# 33      [12, 4239, 4005, 26, 2, 441, 1786, 1244, 7, 27...    0.157135
# 56      [12, 4408, 6544, 5467, 10, 8, 2773, 174, 149, ...    0.077152
# 67      [126974, 1, 42, 5326, 22566, 1, 10, 2, 1173, 4...    0.000000
# 86      [647, 5238, 20, 246, 160, 1, 6907, 179, 246, 4...    0.000000
# 97      [26818, 126992, 20, 96, 788, 328, 1122, 19, 10...    0.000000
# ...                                                   ...         ...
# 142202  [2162, 30, 31, 32, 27, 643, 949, 483, 34468, 1...    0.000000
# 142231  [30, 31, 32, 27, 624, 8, 50, 124, 23, 793, 14,...    0.133333
# 142269  [30, 31, 32, 27, 218, 67, 204, 337, 4, 7112, 9...    0.055048
# 142302  [926, 30, 31, 32, 27, 503, 68, 764, 14857, 980...    0.000000
# 142304  [69, 128, 30, 31, 32, 27, 3057, 4164, 10536, 4...    0.000000
#
# [25516 rows x 5 columns]

# %%
train_split.to_csv('/content/gdrive/MyDrive/NLP-Project/train_split.csv')
test_split.to_csv('/content/gdrive/MyDrive/NLP-Project/test_split.csv')

# %%
np.random.seed(7)
X_train = sequence.pad_sequences(train_split['encoding'],maxlen = 500)
y_train = train_split['label']
y_train = tf.one_hot(y_train,depth = 2)
X_test = sequence.pad_sequences(test_split['encoding'],maxlen=500)
y_test = test_split['label']
y_test = tf.one_hot(y_test,depth = 2)

# %%
embedding_vector_length = 32
model = Sequential()
model.add(Embedding(40000,embedding_vector_length,input_length = 500))
model.add(GRU(32,dropout=0.2, return_sequences = True ))
model.add(GRU(32))
model.add(Dense(2,activation = 'softmax'))
model.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/gdrive/MyDrive/NLP-Project/checkpoints', save_weights_only=True, monitor='val_accuracy', mode='max', save_best_only=True)
print(model.summary())
model.fit(X_train,y_train, epochs = 30, batch_size=500,callbacks = [model_checkpoint_callback])
scores = model.evaluate(X_test, y_test, verbose =0)
print("Accuracy: ",(scores[1]*100))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 32)           1280000
#
#  gru (GRU)                   (None, 500, 32)           6336
#
#  gru_1 (GRU)                 (None, 32)                6336
#
#  dense (Dense)               (None, 2)                 66
#
# =================================================================
# Total params: 1,292,738
# Trainable params: 1,292,738
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 423/423 [==============================] - ETA: 0s - loss: 0.6309 - accuracy: 0.6766WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 72s 150ms/step - loss: 0.6309 - accuracy: 0.6766
# Epoch 2/30
# 423/423 [==============================] - ETA: 0s - loss: 0.6272 - accuracy: 0.6769WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.6272 - accuracy: 0.6769
# Epoch 3/30
# 423/423 [==============================] - ETA: 0s - loss: 0.6130 - accuracy: 0.6770WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.6130 - accuracy: 0.6770
# Epoch 4/30
# 423/423 [==============================] - ETA: 0s - loss: 0.5989 - accuracy: 0.6797WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 151ms/step - loss: 0.5989 - accuracy: 0.6797
# Epoch 5/30
# 423/423 [==============================] - ETA: 0s - loss: 0.5840 - accuracy: 0.6837WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.5840 - accuracy: 0.6837
# Epoch 6/30
# 423/423 [==============================] - ETA: 0s - loss: 0.5692 - accuracy: 0.6898WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.5692 - accuracy: 0.6898
# Epoch 7/30
# 423/423 [==============================] - ETA: 0s - loss: 0.5538 - accuracy: 0.6966WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.5538 - accuracy: 0.6966
# Epoch 8/30
# 423/423 [==============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.7009WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.5376 - accuracy: 0.7009
# Epoch 9/30
# 423/423 [==============================] - ETA: 0s - loss: 0.5221 - accuracy: 0.7059WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.5221 - accuracy: 0.7059
# Epoch 10/30
# 423/423 [==============================] - ETA: 0s - loss: 0.5081 - accuracy: 0.7109WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.5081 - accuracy: 0.7109
# Epoch 11/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4942 - accuracy: 0.7166WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.4942 - accuracy: 0.7166
# Epoch 12/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4818 - accuracy: 0.7205WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4818 - accuracy: 0.7205
# Epoch 13/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4712 - accuracy: 0.7240WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.4712 - accuracy: 0.7240
# Epoch 14/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4612 - accuracy: 0.7282WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.4612 - accuracy: 0.7282
# Epoch 15/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4528 - accuracy: 0.7298WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.4528 - accuracy: 0.7298
# Epoch 16/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4445 - accuracy: 0.7329WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.4445 - accuracy: 0.7329
# Epoch 17/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.7375WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4378 - accuracy: 0.7375
# Epoch 18/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4311 - accuracy: 0.7399WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4311 - accuracy: 0.7399
# Epoch 19/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4247 - accuracy: 0.7435WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.4247 - accuracy: 0.7435
# Epoch 20/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4191 - accuracy: 0.7463WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.4191 - accuracy: 0.7463
# Epoch 21/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4147 - accuracy: 0.7499WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.4147 - accuracy: 0.7499
# Epoch 22/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4103 - accuracy: 0.7520WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.4103 - accuracy: 0.7520
# Epoch 23/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4052 - accuracy: 0.7551WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.4052 - accuracy: 0.7551
# Epoch 24/30
# 423/423 [==============================] - ETA: 0s - loss: 0.4006 - accuracy: 0.7576WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.4006 - accuracy: 0.7576
# Epoch 25/30
# 423/423 [==============================] - ETA: 0s - loss: 0.3967 - accuracy: 0.7612WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 64s 150ms/step - loss: 0.3967 - accuracy: 0.7612
# Epoch 26/30
# 423/423 [==============================] - ETA: 0s - loss: 0.3929 - accuracy: 0.7649WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.3929 - accuracy: 0.7649
# Epoch 27/30
# 423/423 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.7671WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.3892 - accuracy: 0.7671
# Epoch 28/30
# 423/423 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.7704WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.3852 - accuracy: 0.7704
# Epoch 29/30
# 423/423 [==============================] - ETA: 0s - loss: 0.3819 - accuracy: 0.7716WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.3819 - accuracy: 0.7716
# Epoch 30/30
# 423/423 [==============================] - ETA: 0s - loss: 0.3798 - accuracy: 0.7757WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 423/423 [==============================] - 63s 150ms/step - loss: 0.3798 - accuracy: 0.7757
# Accuracy:  69.88556385040283

# %%
embedding_vector_length = 32
model = Sequential()
model.add(Embedding(40000,embedding_vector_length,input_length = 500))
model.add(GRU(32,dropout=0.2, return_sequences = True ))
model.add(GRU(32))
model.add(Dense(2,activation = 'softmax'))
model.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/gdrive/MyDrive/GCDC_rerelease/checkpoints', save_weights_only=True, monitor='val_accuracy', mode='max', save_best_only=True)
print(model.summary())
model.fit(X_train,y_train, epochs = 20, batch_size=82,callbacks = [model_checkpoint_callback])
scores = model.evaluate(X_test, y_test, verbose =0)
print("Accuracy: ",(scores[1]*100))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 500, 32)           1280000
#
#  gru_2 (GRU)                 (None, 500, 32)           6336
#
#  gru_3 (GRU)                 (None, 32)                6336
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 1,292,738
# Trainable params: 1,292,738
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 2579/2579 [==============================] - ETA: 0s - loss: 0.6300 - accuracy: 0.6769WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 2579/2579 [==============================] - 518s 200ms/step - loss: 0.6300 - accuracy: 0.6769
# Epoch 2/20
#  734/2579 [=======>......................] - ETA: 6:07 - loss: 0.6286 - accuracy: 0.6780
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-986c0e686a50> in <module>()
#       8 model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/gdrive/MyDrive/GCDC_rerelease/checkpoints', save_weights_only=True, monitor='val_accuracy', mode='max', save_best_only=True)
#       9 print(model.summary())
# ---> 10 model.fit(X_train,y_train, epochs = 20, batch_size=82,callbacks = [model_checkpoint_callback])
#      11 scores = model.evaluate(X_test, y_test, verbose =0)
#      12 print("Accuracy: ",(scores[1]*100))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
model.save('/content/gdrive/MyDrive/NLP-Project/new_data_lstm_model')

# %%
np.random.seed(7)
X_train = sequence.pad_sequences(train_split['encoding'],maxlen = 500)
y_train = train_split['label']
y_train = tf.one_hot(y_train,depth = 2)
X_test = sequence.pad_sequences(test_split['encoding'],maxlen=500)
y_test = test_split['label']
y_test = tf.one_hot(y_test,depth = 2)

X_train = np.append(train_split['similarity'][:,np.newaxis], X_train, axis=1)
X_test = np.append(test_split['similarity'][:,np.newaxis],X_test, axis=1)

embedding_vector_length = 32
model = Sequential()
model.add(Embedding(40000,embedding_vector_length,input_length = 501))
model.add(GRU(32,dropout=0.2, return_sequences = True ))
model.add(GRU(32))
model.add(Dense(2,activation = 'softmax'))
model.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])
print(model.summary())
model.fit(X_train,y_train, epochs = 20 , batch_size=500)

scores = model.evaluate(X_test, y_test, verbose =0)
print("Accuracy: ",(scores[1]*100))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # Remove the CWD from sys.path while we load stuff.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 501, 32)           1280000
#
#  gru_6 (GRU)                 (None, 501, 32)           6336
#
#  gru_7 (GRU)                 (None, 32)                6336
#
#  dense_3 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 1,292,738
# Trainable params: 1,292,738
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 423/423 [==============================] - 67s 151ms/step - loss: 0.6313 - accuracy: 0.6769
# Epoch 2/20
# 423/423 [==============================] - 64s 150ms/step - loss: 0.6260 - accuracy: 0.6769
# Epoch 3/20
# 423/423 [==============================] - 64s 150ms/step - loss: 0.6122 - accuracy: 0.6768
# Epoch 4/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.5996 - accuracy: 0.6795
# Epoch 5/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.5852 - accuracy: 0.6843
# Epoch 6/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.5695 - accuracy: 0.6903
# Epoch 7/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.5528 - accuracy: 0.6973
# Epoch 8/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.5359 - accuracy: 0.7029
# Epoch 9/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.5195 - accuracy: 0.7082
# Epoch 10/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.5044 - accuracy: 0.7132
# Epoch 11/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4911 - accuracy: 0.7173
# Epoch 12/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4786 - accuracy: 0.7224
# Epoch 13/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4676 - accuracy: 0.7255
# Epoch 14/20
# 423/423 [==============================] - 64s 150ms/step - loss: 0.4577 - accuracy: 0.7294
# Epoch 15/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4494 - accuracy: 0.7328
# Epoch 16/20
# 423/423 [==============================] - 64s 150ms/step - loss: 0.4412 - accuracy: 0.7367
# Epoch 17/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4351 - accuracy: 0.7391
# Epoch 18/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4278 - accuracy: 0.7425
# Epoch 19/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4214 - accuracy: 0.7468
# Epoch 20/20
# 423/423 [==============================] - 64s 151ms/step - loss: 0.4161 - accuracy: 0.7496
# Accuracy:  77.75905132293701

# %%
data1 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Clinton_train.csv')
data2 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Yahoo_train.csv')
data3 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Yelp_train.csv')
data4 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Enron_train.csv')

data5 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Yahoo_test.csv')
data6 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Yelp_test.csv')
data7 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Enron_test.csv')
data8 = pd.read_csv('/content/gdrive/MyDrive/NLP-Project/Enron_test.csv')
